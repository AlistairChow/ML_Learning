# %%
#-*- coding:utf8 -*-
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

sns.set(color_codes=True)

# %%
titanic_data = 'titanic-data.csv'
titanic_df = pd.read_csv(titanic_data)

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Data Dictionary
# |Variable|Definition|	Key|
# |:--|:--|:--|
# |survival|	Survival|	0 = No, 1 = Yes|
# |pclass|	Ticket class|	1 = 1st, 2 = 2nd, 3 = 3rd|
# |sex|	Sex||
# |Age|	Age in years||
# |sibsp|	# of siblings / spouses aboard the Titanic||
# |parch|	# of parents / children aboard the Titanic||
# |ticket|	Ticket number||
# |fare|	Passenger fare||
# |cabin|	Cabin number||
# |embarked|	Port of Embarkation|	C = Cherbourg, Q = Queenstown, S = Southampton|
# ### Variable Notes
#
# **pclass**: A proxy for socio-economic status (SES)
# 1st = Upper
# 2nd = Middle
# 3rd = Lower
#
# **age**: Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5
#
# **sibsp**: The dataset defines family relations in this way...
# Sibling = brother, sister, stepbrother, stepsister
# Spouse = husband, wife (mistresses and fiancés were ignored)
#
# **parch**: The dataset defines family relations in this way...
# Parent = mother, father
# Child = daughter, son, stepdaughter, stepson
# Some children travelled only with a nanny, therefore parch=0 for them.

# %% [markdown]
# # 1 问题探索

# %% [markdown]
# 哪些因素可以让船上的人生还率更高？

# %% [markdown]
# # 2 数据整理

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# 从上图众可以发现，Age, Cabin及Embarked存在缺失值的情况

# %% [markdown]
# ## 2.1 缺失值处理

# %% [markdown]
# ### 2.1.1 Age

# %% [markdown]
# Age的缺失值, 用Age的均值进行填充

# %%
titanic_df.Age = titanic_df.Age.fillna(titanic_df.Age.mean())

# %% [markdown]
# ### 2.1.2 Cabin

# %% [markdown]
# 由于Cabin存在大量缺失值，且Cabin没有明显众数，故让Cabin的缺失值赋予一个新值'None'

# %%
titanic_df.Cabin = titanic_df.Cabin.fillna('None')

# %% [markdown]
# ### 2.1.3 Embarked

# %%
titanic_df.groupby('Embarked').count().Survived
# Out:
# Embarked
# C    168
# Q     77
# S    644
# Name: Survived, dtype: int64

# %% [markdown]
# 可以看出Embarked的众数为S，所以将缺失值填充为S

# %%
titanic_df.Embarked = titanic_df.Embarked.fillna('S')

# %% [markdown]
# ## 2.2 数据复核

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            891 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          891 non-null object
# Embarked       891 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# 可以看到处理过后数据的各属性均为891条，即已经没有缺失值。

# %% [markdown]
# # 3 定义公共函数

# %%
# 绘制柱状图
def draw_bar_figure(data, labels=None):
    data.plot.bar()
    if labels is None:
        plt.xticks(fontsize=15)
    else:
        plt.xticks(np.arange(len(labels)), labels, fontsize=15)
    plt.yticks(fontsize=15)
    plt.ylabel('Number of passengers')

# 绘制饼状图    
def draw_pie_figure(data, labels=None):
    _, texts, autotext = plt.pie(data,
    labels=labels,
    autopct='%.3f%%')
    
    for t in texts:
        t.set_size(15)
    for t in autotext:
        t.set_size(15) 
        
# 绘制柱状图及饼状图 
def draw_bar_pie_figure(serise, lables=None):
    plt.figure(figsize=(10,5))
    plt.subplot(121)
    draw_bar_figure(serise, lables)

    plt.subplot(122)
    draw_pie_figure(serise, lables)
    
def variable_visulization(feature):
    '''各个因素对生还率的影响分析对比柱状图组合'''
    f, ax = plt.subplots(1, 2, figsize=(16, 6))
    # 左侧显示幸存人数对比柱状图
    titanic_df.groupby([feature, 'Survived']).Survived.count().unstack().plot(kind='bar', stacked=True, ax=ax[0])
    ax[0].set_ylabel('Number of passengers')
    ax[0].set_title(feature + ' VS Survived VS Count')
    # 右侧显示幸存几率柱状图
    titanic_df.groupby(feature).Survived.mean().plot(kind='bar', ax=ax[1])
    ax[1].set_ylabel('Survived Rate')
    ax[1].set_title(feature + ' VS Survival Rate')
    plt.show()

# %% [markdown]
# # 4 泰坦尼克号总体情况

# %% [markdown]
# ## 4.1 男女人数及比例

# %%
male_count = titanic_df.Sex.value_counts()['male']
female_count = titanic_df.Sex.value_counts()['female']
sex_rate = round(float(male_count) / female_count,3)

print "船上男性人数为{}人, 女性人数为{}人, 男女比例为{}".format(male_count, female_count, sex_rate)
# Out:
# 船上男性人数为577人, 女性人数为314人, 男女比例为1.838

# %%
draw_bar_pie_figure(titanic_df.Sex.value_counts(), ('male', 'female'))

# %% [markdown]
# ## 4.2 客舱人数及比例

# %%
pclass_counts = titanic_df.Pclass.value_counts()
print "船上高级客舱人数为{}人, 中级客舱人数为{}人, 低级客舱人数为{}".format(pclass_counts[1], pclass_counts[2], pclass_counts[3])
# Out:
# 船上高级客舱人数为216人, 中级客舱人数为184人, 低级客舱人数为491

# %%
draw_bar_pie_figure(titanic_df.Pclass.value_counts().sort_index(), ('Upper', 'Middle', 'Lower'))

# %% [markdown]
# ## 4.3 乘客年龄分布

# %% [markdown]
# ### 4.3.1 年龄大致分布情况

# %%
titanic_df.Age.hist(bins = 10)

# %% [markdown]
# 根据上图可以看出，乘客年龄大致集中在18-45岁之间

# %% [markdown]
# ### 4.3.2 对年龄进行分组

# %%
# 对年龄进行分组，每10岁一组
bins = np.arange(0, 90, 10)
# 添加Age_group字段
titanic_df['Age_group'] = pd.cut(titanic_df['Age'], bins)

age_group_counts = titanic_df.Age_group.value_counts()

# %%
plt.figure(figsize=(10,5))
plt.subplot(121)
draw_bar_figure(age_group_counts.sort_index())

plt.subplot(122)    
draw_pie_figure(age_group_counts.get_values(), age_group_counts.index)

# %% [markdown]
# 可以发现，乘客主要集中在20-50岁

# %% [markdown]
# ## 4.4 港口上船人数及比例

# %%
embarked_counts = titanic_df.Embarked.value_counts()
print '瑟堡上船人数为{}人， 昆士城上船人数为{}人，南安普敦上船人数为{}人'.format(
    embarked_counts['C'], 
    embarked_counts['Q'], 
    embarked_counts['S'])
# Out:
# 瑟堡上船人数为168人， 昆士城上船人数为77人，南安普敦上船人数为646人

# %%
plt.figure(figsize=(10, 5))
plt.subplot(121)
draw_bar_figure(embarked_counts)

plt.subplot(122)
draw_pie_figure(embarked_counts.get_values(), embarked_counts.index)

# %% [markdown]
# ## 4.5 上船港与舱位关系

# %%
embarked_pclass_group = titanic_df.groupby(['Embarked','Pclass'])
embarked_pclass_rate = embarked_pclass_group.count().Survived / titanic_df.groupby('Embarked').Survived.count()

x = np.arange(1, 4)
width = 0.3
plt.bar(x-width, embarked_pclass_rate.C, width)
plt.bar(x, embarked_pclass_rate.Q, width)
plt.bar(x+width, embarked_pclass_rate.S, width)
plt.xlabel('Pclass')
plt.ylabel('Count')
plt.xticks((1, 2, 3), ('Upper', 'Middle', 'Lower'))
plt.legend(['Cherbourg', 'Queenstown', 'Southampton'])

# %% [markdown]
# **结论**:由昆士城上船的人大多买的Lower仓（平民多），由瑟堡上船的人基本集中在Upper和Middle仓(有钱人多)

# %% [markdown]
# # 5 泰坦尼克生还率情况

# %% [markdown]
# ## 5.1 总体生还率

# %%
survived_rate = round(titanic_df.Survived.sum() / float(titanic_df.Survived.count()),3)
print '泰坦尼克号总人数为{}人，生还人数为{}人，生还率为{}'.format(titanic_df.Survived.count(),
                                            titanic_df.Survived.sum(),
                                            survived_rate)
# Out:
# 泰坦尼克号总人数为891人，生还人数为342人，生还率为0.384

# %%
draw_bar_pie_figure(titanic_df.Survived.value_counts(), ('not survived', 'survived'))

# %% [markdown]
# ## 5.2 性别与生还率

# %%
variable_visulization('Sex')

# %%
male_df = titanic_df[titanic_df.Sex == 'male']
female_df = titanic_df[titanic_df.Sex == 'female']

# %% [markdown]
# ### 5.2.1 男性生还率

# %%
draw_bar_pie_figure(male_df.Survived.value_counts().sort_index(), ('not survived', 'survived'))

# %% [markdown]
# ### 5.2.2 女性生还率

# %%
draw_bar_pie_figure(female_df.Survived.value_counts().sort_index(), ('not survived', 'survived'))

# %% [markdown]
# **结论**：男性的生还率(18.891%)远低于女性生还率(74.204%)

# %% [markdown]
# ## 5.3 舱位与生还率

# %%
variable_visulization('Pclass')

# %%
class1_df = titanic_df[titanic_df.Pclass == 1]
class2_df = titanic_df[titanic_df.Pclass == 2]
class3_df = titanic_df[titanic_df.Pclass == 3]

# %% [markdown]
# ### 5.3.1 Upper舱位生还率

# %%
draw_bar_pie_figure(class1_df.Survived.value_counts().sort_index(), ('not survived', 'survived'))

# %% [markdown]
# ### 5.3.2 Middle舱位生还率

# %%
draw_bar_pie_figure(class2_df.Survived.value_counts().sort_index(), ('not survived', 'survived'))

# %% [markdown]
# ### 5.3.3 Lower舱位生还率

# %%
draw_bar_pie_figure(class3_df.Survived.value_counts().sort_index(), ('not survived', 'survived'))

# %% [markdown]
# **结论**：Upper舱位生还率(62.963%)最高，Middle舱位生还率(47.283%)次之，Lower舱位虽然人数最多，但获救率(24.236%)最低

# %% [markdown]
# ### 5.3.4 舱位与性别与生还率

# %%
pclass_sex_group = titanic_df.groupby(['Sex', 'Pclass'])
survived_rate = (pclass_sex_group.sum()/pclass_sex_group.count()).Survived

x = np.arange(1, 4)
width = 0.3
plt.bar(x-width, survived_rate.female, width)
plt.bar(x, survived_rate.male, width)
plt.xlabel('Pclass')
plt.ylabel('Survived Rate')
plt.xticks((1, 2, 3), ('Upper', 'Middle', 'Lower'))
plt.legend(['female', 'male'])

# %% [markdown]
# **结论**：舱位等级越高生还率越高，同舱位女性生还率高于男性

# %% [markdown]
# # 5.4 上船港口与生还率

# %%
variable_visulization('Embarked')

# %%
embarked_c_df = titanic_df[titanic_df.Embarked == 'C']
embarked_q_df = titanic_df[titanic_df.Embarked == 'Q']
embarked_s_df = titanic_df[titanic_df.Embarked == 'S']

# %% [markdown]
# ### 5.4.1 瑟堡生还率

# %%
draw_bar_pie_figure(embarked_c_df.Survived.value_counts().sort_index(), ('not survived', 'survived'))

# %% [markdown]
# ### 5.4.2 昆士城生还率

# %%
draw_bar_pie_figure(embarked_q_df.Survived.value_counts().sort_index(), ('not survived', 'survived'))

# %% [markdown]
# ### 5.4.3 南安普敦

# %%
draw_bar_pie_figure(embarked_s_df.Survived.value_counts().sort_index(), ('not survived', 'survived'))

# %% [markdown]
# **结论**：瑟堡生还率(55.357%)最高，昆士城(38.961%)次之，南安普敦(33.696%)最低

# %% [markdown]
# ## 5.5 年龄与生还率

# %%
variable_visulization('Age_group')

# %% [markdown]
# ### 5.5.1 按照年龄分组查看

# %%
#根据年龄分组（10岁一组）进行查看生还率情况
(titanic_df.groupby('Age_group').sum() / titanic_df.groupby('Age_group').count()).Survived.plot.bar()

# %% [markdown]
# ### 5.5.2 按照年龄查看

# %% [markdown]
# **结论**：可以看出年幼的生还率较高

# %% [markdown]
# # 6 总结

# %% [markdown]
# 本次分析主要为了探索哪些因素（性别，年龄，舱位，上船港口等）可以让船上的人生还率更高，通过数据分析，统计结果如下：
# 1.样本数据量有891条，生还人数为342人，样本生还率为0.384
# 2.船上男性人数为577人, 女性人数为314人, 男女比例为1.838，男性的生还率(18.891%)远低于女性生还率(74.204%)
# 3.样本中有年龄的条目仅有714条，存在177条年龄数据缺失，缺失值按年龄的平均值进行补充，暂时得出结论，乘客主要集中在20-50岁，10岁以下的幼童生还率较高
# 4.船上高级客舱人数为216人, 中级客舱人数为184人, 低级客舱人数为491，Upper舱位生还率(62.963%)最高，Middle舱位生还率(47.283%)次之，Lower舱位虽然人数最多，但获救率(24.236%)最低
# 5.上船港口有两条缺失数据，用众数S进行填充。据统计瑟堡上船人数为168人， 昆士城上船人数为77人，南安普敦上船人数为646人，瑟堡生还率(55.357%)最高，昆士城(38.961%)次之，南安普敦(33.696%)最低。由昆士城上船的人大多买的Lower仓（平民多），由瑟堡上船的人基本集中在Upper和Middle仓(有钱人多)。
# 从统计上暂时可以得出结论：
# 泰坦尼克号的生还率与性别，年龄及舱位（富裕层度）存在一定的相关性，年龄小于十岁，性别为女性，Upper仓那么其生还率较大。上船港口与舱位有一定的相关性，但与生还率没有太大的关系。生还率可能还与其他因素也有关系，如个人的职业，，是否是船员，是否会游泳，身体素质等。
